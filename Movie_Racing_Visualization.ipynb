# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ast

# %%
df = pd.read_csv("movie_rating_Dataset.csv",low_memory=False)
df.head()
# Out:
#   movie_id                                     title  \
# 0    19995                                    Avatar
# 1      285  Pirates of the Caribbean: At World's End
# 2   206647                                   Spectre
# 3    49026                     The Dark Knight Rises
# 4    49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew Unnamed: 4 Unnamed: 5  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...        NaN        NaN
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...        NaN        NaN
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...        NaN        NaN
# ...

# %%
data.head()
# Out:
#   movie_id                                     title  \
# 0    19995                                    Avatar
# 1      285  Pirates of the Caribbean: At World's End
# 2   206647                                   Spectre
# 3    49026                     The Dark Knight Rises
# 4    49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew Unnamed: 4 Unnamed: 5  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...        NaN        NaN
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...        NaN        NaN
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...        NaN        NaN
# ...

# %%
df.shape
# Out:
# (4813, 1265)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4813 entries, 0 to 4812
# Columns: 1265 entries, movie_id to Unnamed: 1264
# dtypes: object(1265)
# memory usage: 46.5+ MB

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
df.isnull().sum()
# Out:
# movie_id    0
# title       0
# cast        0
# crew        0
# dtype: int64

# %%
data.describe()
# Out:
#           cast_size
# count   4813.000000
# mean    3363.850613
# std     3080.147849
# min        2.000000
# 25%     1670.000000
# 50%     2487.000000
# 75%     3851.000000
# max    32759.000000

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['cast_size'], bins=20)
plt.title("Distribution of Cast Size")
plt.xlabel("Number of Actors")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['crew_size'], bins=20)
plt.title("Distribution of Crew Size")
plt.xlabel("Number of Crew Members")
plt.ylabel("Frequency")
plt.show()

# %%
df['cast_size'] = df['cast'].apply(len)
df['crew_size'] = df['crew'].apply(len)

# %% [markdown]
# In this project, we cleaned and analyzed a movie dataset and created visualizations to understand the distribution of cast and crew sizes. The results show that most movies have moderate team sizes, while a few have very large productions. This project highlights the importance of data cleaning, feature engineering, and visualization in data analysis.
